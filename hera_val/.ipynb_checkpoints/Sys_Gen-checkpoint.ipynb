# %%
# !pip install uvtools
# Out:
# Collecting uvtools
#   Downloading uvtools-0.2.0.tar.gz (7.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.7/7.7 MB 3.7 MB/s eta 0:00:0000:0100:01m
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: numpy in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from uvtools) (1.26.3)
# Requirement already satisfied: six in /Users/user/Library/Python/3.12/lib/python/site-packages (from uvtools) (1.16.0)
# Requirement already satisfied: scipy in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from uvtools) (1.11.4)
# Requirement already satisfied: pyuvdata in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from uvtools) (2.4.3)
# Requirement already satisfied: astropy>5.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from uvtools) (6.0.1)
# Requirement already satisfied: pyerfa>=2.0.1.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from astropy>5.1->uvtools) (2.0.1.4)
# Requirement already satisfied: astropy-iers-data>=0.2024.2.26.0.28.55 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from astropy>5.1->uvtools) (0.2024.4.22.0.29.50)
# Requirement already satisfied: PyYAML>=3.13 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from astropy>5.1->uvtools) (6.0.1)
# Requirement already satisfied: packaging>=19.0 in /Users/user/Library/Python/3.12/lib/python/site-packages (from astropy>5.1->uvtools) (23.2)
# Requirement already satisfied: docstring-parser>=0.15 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from pyuvdata->uvtools) (0.16)
# Requirement already satisfied: h5py>=3.4 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from pyuvdata->uvtools) (3.11.0)
# Requirement already satisfied: setuptools>=61 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from pyuvdata->uvtools) (69.0.3)
# Requirement already satisfied: setuptools-scm!=7.0.0,!=7.0.1,!=7.0.2 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from pyuvdata->uvtools) (8.0.4)
# Requirement already satisfied: typing-extensions in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from setuptools-scm!=7.0.0,!=7.0.1,!=7.0.2->pyuvdata->uvtools) (4.9.0)
# Building wheels for collected packages: uvtools
#   Building wheel for uvtools (pyproject.toml) ... done
#   Created wheel for uvtools: filename=uvtools-0.2.0-py3-none-any.whl size=4492825 sha256=113698cec84ab8380384b17b0c6327ad51770f63d24d8f3c85a6577ed415339f
#   Stored in directory: /Users/user/Library/Caches/pip/wheels/14/a6/82/68d9cbf06b9a6c2543e28d0825ae38636ab01d3878c425c2f5
# Successfully built uvtools
# Installing collected packages: uvtools
# Successfully installed uvtools-0.2.0

# %%
import numpy as np
import matplotlib.pyplot as plt
import hera_sim
from hera_sim import Simulator

# %%
from pyuvdata import UVData

# %%
from uvtools.plot import labeled_waterfall

# %%
def waterfall(sim, antpairpol=(0,1,"xx"), figsize=(6,3.5), dpi=200, title=None):
    """Convenient plotting function to show amp/phase."""
    fig, (ax1, ax2) = plt.subplots(
        nrows=2,
        ncols=1,
        figsize=figsize,
        dpi=dpi,
    )
    fig, ax1 = labeled_waterfall(
        sim.data,
        antpairpol=antpairpol,
        mode="log",
        ax=ax1,
        set_title=title,
    )
    ax1.set_xlabel(None)
    ax1.set_xticklabels(['' for tick in ax1.get_xticks()])
    fig, ax2 = labeled_waterfall(
        sim.data,
        antpairpol=antpairpol,
        mode="phs",
        ax=ax2,
        set_title=False,
    )
    return fig

# %%
UV = UVData()

#Foregrounds + EoR signal
UV.read(filename='/Users/user/Documents/Codes/hydra-pspec/test_data/vis-eor-fgs.uvh5')
# Out:
# Telescope Hex37-14.6m is not in known_telescopes.

# %%
sim = Simulator(data=UV.copy())
hera_sim.defaults.set("h1c")
# Out:
# The use_grid_alg parameter is not set. Defaulting to True to use the new gridding based algorithm (developed by the HERA team) rather than the older clustering based algorithm. This is change to the default, to use the clustering algorithm set use_grid_alg=False.

# %%
#Plot true data
fig1 = waterfall(sim, antpairpol=(0,1,"xx"), title="Baseline (0,1)")
# Out:
# set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.

# %% [markdown]
# ### Add Systematics

# %%
#Gains
sim.add(component="gains",seed=1585957365)

# %%
#10 coupling peaks with randomisation
sim.add(component="CrossCouplingSpectrum", n_copies=10,
            amp_range=(-4,-6), dly_range=(900,1300), phs_range=(-np.pi,np.pi),
                amp_jitter=0.01, dly_jitter=20, seed=1585964131, symmetrize=True)
# Out:
# You are adding visibilities to a data array *after* multiplicative effects have been introduced.
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/hg/70vc82sj49g_2x7dh5q_42pc0000gp/T/ipykernel_40686/2788492561.py in ?()
#       1 #10 coupling peaks with randomisation
# ----> 2 sim.add(component="CrossCouplingSpectrum", n_copies=10,
#       3             amp_range=(-4,-6), dly_range=(900,1300), phs_range=(-np.pi,np.pi),
#       4                 amp_jitter=0.01, dly_jitter=20, seed=1585964131, symmetrize=True)
#
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/hera_sim/simulate.py in ?(self, component, add_vis, ret_vis, seed, vis_filter, component_name, **kwargs)
#     296                 stacklevel=2,
#     297             )
#     298
#     299         # Simulate the effect by iterating over baselines and polarizations.
# --> 300         data = self._iteratively_apply(
#     301             model,
#     302             add_vis=add_vis,
#     303             ret_vis=ret_vis,
#
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/hera_sim/simulate.py in ?(self, model, add_vis, ret_vis, seed, vis_filter, antpairpol_cache, **kwargs)
#    1093                 key = (ant2, ant1, pol) if conj_in_cache else (ant1, ant2, pol)
#    1094                 seed = self._seed_rng(seed, model, *key)
#    1095
#    1096                 # Prepare the actual arguments to be used.
# -> 1097                 use_args = self._update_args(base_args, model, ant1, ant2, pol)
#    1098                 use_args.update(kwargs)
#    1099                 if use_cached_filters:
#    1100                     filter_kwargs = self._get_filters(
#
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/hera_sim/simulate.py in ?(self, args, model, ant1, ant2, pol)
#    1303         # TODO: review this and see if there's a smarter way to do it.
#    1304         new_params = {}
#    1305         for param, attr in model.attrs_to_pull.items():
#    1306             if param in ("autovis", "autovis_i"):
# -> 1307                 new_params[param] = self.data.get_data(ant1, ant1, pol)
#    1308             elif param == "autovis_j":
#    1309                 new_params[param] = self.data.get_data(ant2, ant2, pol)
#    1310             elif param == "bl_vec":
#
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pyuvdata/uvdata/uvdata.py in ?(self, key1, key2, key3, squeeze, force_copy)
#    4176             elif val is not None:
#    4177                 key += list(uvutils._get_iterable(val))
#    4178         if len(key) > 3:
#    4179             raise ValueError("no more than 3 key values can be passed")
# -> 4180         ind1, ind2, indp = self._key2inds(key)
#    4181         out = self._smart_slicing(
#    4182             self.data_array, ind1, ind2, indp, squeeze=squeeze, force_copy=force_copy
#    4183         )
#
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pyuvdata/uvdata/uvdata.py in ?(self, key)
#    3823             # Key is an antenna pair + pol
#    3824             blt_ind1 = self.antpair2ind(key[0], key[1])
#    3825             blt_ind2 = self.antpair2ind(key[1], key[0])
#    3826             if len(blt_ind1) + len(blt_ind2) == 0:
# -> 3827                 raise KeyError(
#    3828                     "Antenna pair {pair} not found in data".format(
#    3829                         pair=(key[0], key[1])
#    3830                     )
#
# KeyError: 'Antenna pair (0, 0) not found in data'

# %%
#Reflection spectrum/20 subreflections
sim.add(component="reflection_spectrum", n_copies=20,
            amp_range=(-3,-4), dly_range=(200,1000), phs_range=(-np.pi,np.pi), 
            amp_jitter=0.01, dly_jitter=30, seed=2440572501)

# %%
#2 high-amplitude reflections
sim.add(component="reflections",amp=0.003,amp_jitter=0.01,dly=200,dly_jitter=10,seed=2440572505)
sim.add(component="reflections",amp=0.0008,amp_jitter=0.01,dly=1200,dly_jitter=30,seed=2440572506)

# %%
#Plot corrupted data
fig2 = waterfall(sim, antpairpol=(0,1,"xx"), title="Baseline (0,1)")
# Out:
# set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.

# %%
#Save corrupted data
sim.write('vis-eor-fgs-corrupt.uvh5', save_format="uvh5", fix_autos=True, clobber=True)
